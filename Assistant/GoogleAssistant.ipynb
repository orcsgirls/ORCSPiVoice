# %% [markdown]
# ## Google Assistant
#
# This is the code you used earlier to run the Google Assistant on the AIY Voice Kit.

# %%
import argparse
import locale
import logging
import signal
import sys
import time

from aiy.assistant.grpc import AssistantServiceClientWithLed
from aiy.assistant import auth_helpers, device_helpers, device_handler_helpers
from aiy.board import Board
from aiy.leds import Leds, Color

# %% [markdown]
# #### Setup
#
# Here we set the volume (0-100), language and create a logger object allowing all the different parts of the code to write messages to a log - or here to the screen.

# %%
logger = logging.getLogger(__name__)
language, _ = locale.getdefaultlocale()
volume = 10

logging.basicConfig(level=logging.DEBUG)
signal.signal(signal.SIGTERM, lambda signum, frame: sys.exit(0))

credentials = auth_helpers.get_assistant_credentials()
device_model_id, device_id = device_helpers.get_ids_for_service(credentials)
device_handler = device_handler_helpers.DeviceRequestHandler(device_id)

logger.info('device_model_id: %s', device_model_id)
logger.info('device_id: %s', device_id)
# Out:
# DEBUG:google.auth.transport.requests:Making request: POST https://oauth2.googleapis.com/token
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oauth2.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# INFO:__main__:device_model_id: credible-acre-346021-voice-kit
# INFO:__main__:device_id: credible-acre-346021-voice-kit-c4a5e41d-81b9-4282-b312-88075b4aa031

# %% [markdown]
# #### Custom handlers
#
# Once we have configured curom traits (like turning the servo), we need to add the code that handles those requests here.

# %%
#------------------------------------------------------------------------------
# Add custom device handlers here
#------------------------------------------------------------------------------

## None for now

#------------------------------------------------------------------------------

# %% [markdown]
# #### Assistant loop
#
# Here is the main part. Basically it waits for the user to press the button and then calls the assistent.conversation() routine to deal with one convsersation. Once it send it goes back waiting for someone to press the button and so on.

# %%
with Board() as board:
    assistant = AssistantServiceClientWithLed(board=board,
                                              volume_percentage=volume,
                                              language_code=language,
                                              credentials=credentials,
                                              device_model_id=device_model_id,
                                              device_id=device_id,
                                              device_handler=device_handler)

    try:
        while True:
            logging.info('Press button to start conversation...')
            board.button.wait_for_press()
            logging.info('Conversation started!')
            assistant.conversation()
    except KeyboardInterrupt:
        print("Bye")
# Out:
# DEBUG:google.auth.transport.requests:Making request: POST https://oauth2.googleapis.com/token
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oauth2.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# INFO:aiy.assistant.grpc:Connecting to embeddedassistant.googleapis.com
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "song".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "play".
# INFO:aiy.assistant.grpc:You said: "play at".
# INFO:aiy.assistant.grpc:You said: "play a song".
# INFO:aiy.assistant.grpc:You said: "play  a song".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "play a song".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "open".
# INFO:aiy.assistant.grpc:You said: "open you".
# INFO:aiy.assistant.grpc:You said: "open YouTube".
# INFO:aiy.assistant.grpc:You said: "open YouTube music".
# INFO:aiy.assistant.grpc:You said: "open YouTube  music".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "open YouTube music".
# INFO:aiy.assistant.grpc:You said: "open YouTube music".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "can you".
# INFO:aiy.assistant.grpc:You said: "can you play".
# INFO:aiy.assistant.grpc:You said: "can you play a".
# INFO:aiy.assistant.grpc:You said: "can you play any".
# INFO:aiy.assistant.grpc:You said: "can you  play any".
# INFO:aiy.assistant.grpc:You said: "can you play  any".
# INFO:aiy.assistant.grpc:You said: "can you play  any song".
# INFO:aiy.assistant.grpc:You said: "can you play any  song".
# INFO:aiy.assistant.grpc:You said: "can you play any song".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "can you play any song".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "On the website soundstripe.com, they say: If you want to legally use copyrighted music on YouTube, you'll have to go out and get approval from the original creator in order to use it. That's the second side of music licensing. Copyright law makes sure that creators get paid when people use their work — that's where YouTube's music policy comes into play."
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "when".
# INFO:aiy.assistant.grpc:You said: "when is".
# INFO:aiy.assistant.grpc:You said: "when is the".
# INFO:aiy.assistant.grpc:You said: "when is Saint".
# INFO:aiy.assistant.grpc:You said: "when is sun".
# INFO:aiy.assistant.grpc:You said: "when is sunrise".
# INFO:aiy.assistant.grpc:You said: "when  is sunrise".
# INFO:aiy.assistant.grpc:You said: "when is  sunrise".
# INFO:aiy.assistant.grpc:You said: "when is  sunrise tomorrow".
# INFO:aiy.assistant.grpc:You said: "when is sunrise  tomorrow".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "when is sunrise tomorrow".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "Tomorrow, the sun will rise at 7:09 AM."
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "turn it down".
# INFO:aiy.assistant.grpc:You said: "20 *".
# INFO:aiy.assistant.grpc:You said: "you need a".
# INFO:aiy.assistant.grpc:You said: "anytime bro".
# INFO:aiy.assistant.grpc:You said: "do I need an umbrella".
# INFO:aiy.assistant.grpc:You said: "do I need an umbrella today".
# INFO:aiy.assistant.grpc:You said: "do I need an umbrella tomorrow".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "do I need an umbrella tomorrow".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "tell".
# INFO:aiy.assistant.grpc:You said: "tell me".
# INFO:aiy.assistant.grpc:You said: "tell me a".
# INFO:aiy.assistant.grpc:You said: "tell me a joke".
# INFO:aiy.assistant.grpc:You said: "tell  me a joke".
# INFO:aiy.assistant.grpc:You said: "tell me  a joke".
# INFO:aiy.assistant.grpc:You said: "tell me a  joke".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "tell me a joke".
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "What happened when the geese fell down the stairs?
# They all got goose bumps 😎"
# INFO:aiy.assistant.grpc:Not expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Recording stopped.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:root:Press button to start conversation...
# INFO:root:Conversation started!
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "okay".
# INFO:aiy.assistant.grpc:You said: "okay no".
# INFO:aiy.assistant.grpc:You said: "okay no sir".
# INFO:aiy.assistant.grpc:You said: "okay no sorry".
# INFO:aiy.assistant.grpc:You said: "okay no song".
# INFO:aiy.assistant.grpc:You said: "okay  no song".
# INFO:aiy.assistant.grpc:You said: "okay  no song what".
# INFO:aiy.assistant.grpc:You said: "okay no  song what".
# INFO:aiy.assistant.grpc:You said: "okay no  song What can".
# INFO:aiy.assistant.grpc:You said: "okay no song  What can".
# INFO:aiy.assistant.grpc:You said: "okay no song  What can you".
# INFO:aiy.assistant.grpc:You said: "okay no song What  can you".
# INFO:aiy.assistant.grpc:You said: "okay no song What can  you".
# INFO:aiy.assistant.grpc:You said: "okay no song What can you".
# INFO:aiy.assistant.grpc:You said: "okay no song what can you  do".
# INFO:aiy.assistant.grpc:You said: "okay no song What can you  tell".
# INFO:aiy.assistant.grpc:You said: "okay no song what can you  tell me".
# INFO:aiy.assistant.grpc:You said: "okay no song what can you  tell me a".
# INFO:aiy.assistant.grpc:You said: "okay no song what can you  tell me a riddle".
# INFO:aiy.assistant.grpc:You said: "okay no song what can you tell  me a riddle".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "okay no song what can you tell me a riddle".
# INFO:aiy.assistant.grpc:Recording stopped.
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "Welcome to Riddle Rooms!
# Pick a door, and we'll get started
# Which one do you want, "Beginning" or "Other"?"
# INFO:aiy.assistant.grpc:Expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "are".
# INFO:aiy.assistant.grpc:You said: "are the".
# INFO:aiy.assistant.grpc:You said: "are there".
# INFO:aiy.assistant.grpc:You said: "other".
# INFO:aiy.assistant.grpc:You said: "other".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "other".
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "Cool! I wonder what's back there...
# Looks like there's a Skull Door and a Frosty Door
# They let you jump ahead in the adventure
# Which one would you like?"
# INFO:aiy.assistant.grpc:Expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Recording stopped.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Playing stopped.
# INFO:aiy.assistant.grpc:Recording started.
# INFO:aiy.assistant.grpc:You said: "Frost".
# INFO:aiy.assistant.grpc:You said: "Frosty".
# INFO:aiy.assistant.grpc:You said: "Frosty".
# INFO:aiy.assistant.grpc:End of audio request detected.
# INFO:aiy.assistant.grpc:You said: "Frosty".
# DEBUG:aiy.assistant.grpc:Updating conversation state.
# INFO:aiy.assistant.grpc:Assistant said: "Yep, that's definitely frosty.
# I hope you wore your long underwear.
# Room 8
# A clammy corridor calculated to compromise constitutions. I'll put on some soup.
# Riddle: "What can be caught but not thrown, even when a nose is blown?""
# INFO:aiy.assistant.grpc:Expecting follow-on query from user.
# INFO:aiy.assistant.grpc:Playing started.
# INFO:aiy.assistant.grpc:Recording stopped.
# aplay: pcm_write:2053: write error: Interrupted system call
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/AIY-projects-python/src/aiy/assistant/grpc.py in conversation(self, deadline)
#     244                 try:
# --> 245                     keep_talking = self._assist(recorder, wrapped_play, deadline)
#     246                 finally:
#
# ~/AIY-projects-python/src/aiy/assistant/grpc.py in _assist(self, recorder, play, deadline)
#     179                 play(_normalize_audio_buffer(response.audio_out.audio_data,
# --> 180                                              self._volume_percentage))
#     181
#
# ~/AIY-projects-python/src/aiy/assistant/grpc.py in wrapped_play(data)
#     241                         playing = True
# --> 242                     play(data)
#     243
#
# ~/AIY-projects-python/src/aiy/voice/audio.py in push(data)
#     421             if data:
# --> 422                 process.stdin.write(data)
#     423             else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# BrokenPipeError                           Traceback (most recent call last)
# /tmp/ipykernel_999/1445440482.py in <module>
#      13             board.button.wait_for_press()
#      14             logging.info('Conversation started!')
# ---> 15             assistant.conversation()
#      16     except KeyboardInterrupt:
#      17         print("Bye")
#
# ~/AIY-projects-python/src/aiy/assistant/grpc.py in conversation(self, deadline)
#     245                     keep_talking = self._assist(recorder, wrapped_play, deadline)
#     246                 finally:
# --> 247                     play(None)       # Signal end of sound stream.
#     248                     recorder.done()  # Signal stop recording.
#     249
#
# ~/AIY-projects-python/src/aiy/voice/audio.py in push(data)
#     422                 process.stdin.write(data)
#     423             else:
# --> 424                 process.stdin.close()
#     425         return push
#
# BrokenPipeError: [Errno 32] Broken pipe
